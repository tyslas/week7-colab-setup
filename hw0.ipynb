# %% [markdown]
# <a href="https://colab.research.google.com/github/tyslas/week7-colab-setup/blob/main/hw0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Colab\ Notebooks/hw0
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/hw0

# %%
! nvidia-smi
# Out:
# Thu Jun 29 02:30:13 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
torch.__version__
# Out:
# '2.0.1+cu118'

# %%
# %run main.py
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.282550
# Train Epoch: 1 [640/60000 (1%)]	Loss: 1.385107
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 0.905650
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 0.636250
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 0.386161
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.454160
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 0.268887
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 0.705216
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.220847
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 0.318714
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.280128
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 0.191748
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 0.366494
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 0.135858
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 0.378075
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 0.208080
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.259970
# Train Epoch: 1 [10880/60000 (18%)]	Loss: 0.264224
# Train Epoch: 1 [11520/60000 (19%)]	Loss: 0.222581
# ...
